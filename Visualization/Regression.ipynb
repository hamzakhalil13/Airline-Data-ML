# %%
import pandas as pd

# SEABORN IS A PLOTTING LIBRARY
import seaborn as sns

# MATPLOT LIB IS ALSO A PLOTTING LIBRARY
import matplotlib.pyplot as plt

# SKLEARN IS OUR MACHINE LEARNING PACKAGE
from sklearn.linear_model import LinearRegression

# IMPORT OUR RANDOM FOREST REGERSSOR
from sklearn.ensemble import RandomForestRegressor

# METRICS HELP US SCORE OUR MODEL
from sklearn import metrics

# HELP US SPLIT OUR DATA INTO TESTING A TRAINING
from sklearn.model_selection import train_test_split

# HELPER FUNCTION WITH Z-SCORES TO REMOVE OUTLIERS
import scipy.stats as stats

# %%
df = pd.read_csv('/Users/hamzakhalil13/Desktop/Data2/2019_1.csv')
df
# Out:
#               ITIN_ID  YEAR  QUARTER ORIGIN_STATE_NM   DEST_STATE_NM  \
# 0              201912  2019        1    Pennsylvania         Georgia
# 1              201913  2019        1    Pennsylvania         Georgia
# 2              201914  2019        1    Pennsylvania         Georgia
# 3              201915  2019        1    Pennsylvania         Georgia
# 4              201916  2019        1    Pennsylvania         Georgia
# ...               ...   ...      ...             ...             ...
# 2097147  201911841009  2019        1         Florida  North Carolina
# 2097148  201911841009  2019        1  North Carolina         Florida
# 2097149  201911841010  2019        1         Florida  North Carolina
# 2097150  201911841010  2019        1  North Carolina         Florida
# 2097151  201911841011  2019        1         Florida  North Carolina
#
#         TICKET_CARRIER  PASSENGERS  MARKET_FARE  NONSTOP_MILES
# 0                   DL         1.0        36.00          692.0
# ...

# %%
df.shape
# Out:
# (2097152, 9)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 15640

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (2081512, 9)

# %%
# # selected_features = ['NONSTOP_MILES']
# selected_features = list(df.columns)
# selected_features.remove('ITIN_ID')
# selected_features.remove('YEAR')
# selected_features

# %%
condition_1 = df['MARKET_FARE'] < 100

df = df[condition_1]
df
# Out:
#               ITIN_ID  YEAR  QUARTER ORIGIN_STATE_NM DEST_STATE_NM  \
# 0              201912  2019        1    Pennsylvania       Georgia
# 17            2019119  2019        1    Pennsylvania       Georgia
# 18            2019119  2019        1         Georgia  Pennsylvania
# 180          20191105  2019        1    Pennsylvania       Alabama
# 181          20191105  2019        1         Alabama  Pennsylvania
# ...               ...   ...      ...             ...           ...
# 2097132  201911841001  2019        1  North Carolina       Florida
# 2097134  201911841002  2019        1  North Carolina       Florida
# 2097136  201911841003  2019        1  North Carolina       Florida
# 2097138  201911841004  2019        1  North Carolina       Florida
# 2097140  201911841005  2019        1  North Carolina       Florida
#
#         TICKET_CARRIER  PASSENGERS  MARKET_FARE  NONSTOP_MILES
# 0                   DL         1.0        36.00          692.0
# ...

# %%
mean_price = df['MARKET_FARE'].mean()
mean_price
# Out:
# 41.11602320753487

# %%
df = df.drop(columns= ['ORIGIN_STATE_NM', 'DEST_STATE_NM'  ], axis=1)

df
# Out:
#               ITIN_ID  YEAR  QUARTER TICKET_CARRIER  PASSENGERS  MARKET_FARE  \
# 0              201912  2019        1             DL         1.0        36.00
# 17            2019119  2019        1             DL         1.0        14.00
# 18            2019119  2019        1             DL         1.0        14.00
# 180          20191105  2019        1             DL         1.0         5.50
# 181          20191105  2019        1             DL         1.0         5.50
# ...               ...   ...      ...            ...         ...          ...
# 2097132  201911841001  2019        1             DL         1.0        65.18
# 2097134  201911841002  2019        1             DL         1.0        83.27
# 2097136  201911841003  2019        1             DL         1.0        84.53
# 2097138  201911841004  2019        1             DL         1.0        93.78
# 2097140  201911841005  2019        1             DL         1.0        97.14
#
#          NONSTOP_MILES
# ...

# %%
df = pd.get_dummies(df, columns=['TICKET_CARRIER'], drop_first=True)
df
# Out:
#               ITIN_ID  YEAR  QUARTER  PASSENGERS  MARKET_FARE  NONSTOP_MILES  \
# 0              201912  2019        1         1.0        36.00          692.0
# 17            2019119  2019        1         1.0        14.00          692.0
# 18            2019119  2019        1         1.0        14.00          692.0
# 180          20191105  2019        1         1.0         5.50          792.0
# 181          20191105  2019        1         1.0         5.50          792.0
# ...               ...   ...      ...         ...          ...            ...
# 2097132  201911841001  2019        1         1.0        65.18          680.0
# 2097134  201911841002  2019        1         1.0        83.27          680.0
# 2097136  201911841003  2019        1         1.0        84.53          680.0
# 2097138  201911841004  2019        1         1.0        93.78          680.0
# 2097140  201911841005  2019        1         1.0        97.14          680.0
#
# ...

# %%
selected_features = list(df.columns)
selected_features.remove('MARKET_FARE')
selected_features
# Out:
# ['ITIN_ID',
#  'YEAR',
#  'QUARTER',
#  'PASSENGERS',
#  'NONSTOP_MILES',
#  'TICKET_CARRIER_3M',
#  'TICKET_CARRIER_7H',
#  'TICKET_CARRIER_99',
#  'TICKET_CARRIER_9K',
#  'TICKET_CARRIER_AA',
#  'TICKET_CARRIER_AS',
#  'TICKET_CARRIER_B6',
#  'TICKET_CARRIER_BA',
#  'TICKET_CARRIER_BB',
#  'TICKET_CARRIER_DL',
#  'TICKET_CARRIER_EK',
#  'TICKET_CARRIER_HA',
#  'TICKET_CARRIER_QF',
#  'TICKET_CARRIER_UA',
#  'TICKET_CARRIER_VS']

# %%
X = df[selected_features]

y = df['MARKET_FARE']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
model_2 = RandomForestRegressor(random_state=1)

model_2.fit(X_train, y_train)

y_pred = model_2.predict(X_test)

# %%
r_squared = metrics.r2_score(y_test, y_pred)
print('R-Squared Score:', r_squared)
# Out:
# R-Squared Score: 0.3621645631829514

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, roc_auc_score 
accuracy = model_2.score(X_test, y_test)
print("Model Accuracy: %f" % accuracy)
# Out:
# Model Accuracy: 0.362165

# %%
model_3 = RandomForestRegressor(n_estimators=500, max_depth=10, random_state=1)
model_3.fit(X_train, y_train)

y_pred = model_3.predict(X_test)

# %%
r_squared = metrics.r2_score(y_test, y_pred)
print('R-Squared Score:', r_squared)
# Out:
# R-Squared Score: 0.2793065548144993
